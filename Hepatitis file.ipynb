# %%
import pandas as pd
df= pd.read_csv("hepatitis_1 (1).csv")
df.head()
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# ...

# %%
df.dtypes
# Out:
# age                  int64
# sex                 object
# steroid             object
# antivirals            bool
# fatigue             object
# malaise             object
# anorexia            object
# liver_big           object
# liver_firm          object
# spleen_palpable     object
# spiders             object
# ascites             object
# varices             object
# bilirubin          float64
# alk_phosphate      float64
# sgot               float64
# albumin            float64
# protime            float64
# histology             bool
# class               object
# dtype: object

# %%
# I needed to check the type of data that i have in order to know what to clean

# %%
df.describe()
# Out:
#               age   bilirubin  alk_phosphate       sgot     albumin  \
# count  155.000000  149.000000     126.000000  151.00000  139.000000
# mean    41.200000    1.427517     105.325397   85.89404    3.817266
# std     12.565878    1.212149      51.508109   89.65089    0.651523
# min      7.000000    0.300000      26.000000   14.00000    2.100000
# 25%     32.000000    0.700000      74.250000   31.50000    3.400000
# 50%     39.000000    1.000000      85.000000   58.00000    4.000000
# 75%     50.000000    1.500000     132.250000  100.50000    4.200000
# max     78.000000    8.000000     295.000000  648.00000    6.400000
#
#           protime
# count   88.000000
# mean    61.852273
# std     22.875244
# min      0.000000
# 25%     46.000000
# 50%     61.000000
# 75%     76.250000
# max    100.000000

# %%
# I needed to know the statistics so that i can determine what to fill my cacant space with.

# %%
import statistics as stats

# %%
df["alk_phosphate"].median() # to get the median so that i can fill alk_phosphate column with the media in order to have less error.
# Out:
# 85.0

# %%
df["alk_phosphate"].fillna(85.0, inplace=True) # i am filling the missing values of alk_phosphate with the median. i chose median because it is more commom and more accurate.Mean looked more out of line wth a value of 105, the outliner may have huge effect on the mean value. .   
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df["protime"].median()
# Out:
# 61.0

# %%
df["protime"].fillna(61.0, inplace=True)  # i can actually use either mean or median because they arent much difference, i only used median here because it is more common. 
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df.isnull().sum() # i did this to check the columns with missing values so that i can know how to clean it.
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate       0
# sgot                4
# albumin            16
# protime             0
# histology           0
# class               0
# dtype: int64

# %%
df["albumin"].median() #just to obtain the median values on the albumin column to fill up the missing values.
# Out:
# 4.0

# %%
df["albumin"].fillna(4.0, inplace=True) 
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df["sgot"].median() #just to obtain the median values on the albumin column to fill up the missing values.
# Out:
# 58.0

# %%
df["sgot"].fillna(58.0, inplace=True) 
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df["bilirubin"].median() #just to obtain the median values on the albumin column to fill up the missing values.
# Out:
# 1.0

# %%
df["sgot"].fillna(1.0, inplace=True) 
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df.isnull().sum()
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate       0
# sgot                0
# albumin             0
# protime             0
# histology           0
# class               0
# dtype: int64

# %%
df.dropna( inplace=True)  # I  dropped the rest of the empty columns as it is a boolean and i cant fill it with any value in order not to mess the data up.  
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 4     34  female    True       False   False   False    False      True
# 5     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# protime            0
# histology          0
# class              0
# dtype: int64

# %%
df # now my data has 138 rows and still 20 columns. my rows are big enough to obtain vital informations needed for my analysis.
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 4     34  female    True       False   False   False    False      True
# 5     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df["steroid"]= df["steroid"].astype(int)
df
# Out:
#      age     sex  steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male        0       False   False   False    False     False
# 1     50  female        0       False    True   False    False     False
# 2     78  female        1       False    True   False    False      True
# 4     34  female        1       False   False   False    False      True
# 5     34  female        1       False   False   False    False      True
# ..   ...     ...      ...         ...     ...     ...      ...       ...
# 150   46  female        1       False    True    True     True      True
# 151   44  female        1       False    True   False    False      True
# 152   61  female        0       False    True    True    False     False
# 153   53    male        0       False    True   False    False      True
# 154   43  female        1       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
df["antivirals"]= df["antivirals"].astype(int)
df["fatigue"]= df["fatigue"].astype(int)
df["malaise"]= df["malaise"].astype(int)
df["anorexia"]= df["anorexia"].astype(int)
df["liver_big"]= df["liver_big"].astype(int)
df["liver_firm"]= df["liver_firm"].astype(int)
df["spleen_palpable"]= df["spleen_palpable"].astype(int)
df["spiders"]= df["spiders"].astype(int)
df["ascites"]= df["ascites"].astype(int)
df["varices"]= df["varices"].astype(int)
df["histology"]= df["histology"].astype(int)
df
# i changed all my booleans to int so that visulaization can be easier and more accurate
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male        0           0        0        0         0          0
# 1     50  female        0           0        1        0         0          0
# 2     78  female        1           0        1        0         0          1
# 4     34  female        1           0        0        0         0          1
# 5     34  female        1           0        0        0         0          1
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female        1           0        1        1         1          1
# 151   44  female        1           0        1        0         0          1
# 152   61  female        0           0        1        1         0          0
# 153   53    male        0           0        1        0         0          1
# 154   43  female        1           0        1        0         0          1
#
# ...

# %%
df
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male        0           0        0        0         0          0
# 1     50  female        0           0        1        0         0          0
# 2     78  female        1           0        1        0         0          1
# 4     34  female        1           0        0        0         0          1
# 5     34  female        1           0        0        0         0          1
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female        1           0        1        1         1          1
# 151   44  female        1           0        1        0         0          1
# 152   61  female        0           0        1        1         0          0
# 153   53    male        0           0        1        0         0          1
# 154   43  female        1           0        1        0         0          1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              138 non-null    int64
#  1   sex              138 non-null    object
#  2   steroid          138 non-null    int32
#  3   antivirals       138 non-null    int32
#  4   fatigue          138 non-null    int32
#  5   malaise          138 non-null    int32
#  6   anorexia         138 non-null    int32
#  7   liver_big        138 non-null    int32
#  8   liver_firm       138 non-null    int32
#  9   spleen_palpable  138 non-null    int32
#  10  spiders          138 non-null    int32
#  11  ascites          138 non-null    int32
#  12  varices          138 non-null    int32
#  13  bilirubin        138 non-null    float64
#  14  alk_phosphate    138 non-null    float64
#  15  sgot             138 non-null    float64
#  16  albumin          138 non-null    float64
# ...
